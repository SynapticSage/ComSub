# %%
#learning data
import h5py
import numpy as np

data = h5py.File('F:\ComSub\code\ComSub-master\mytry\example_workspace_of_structs.mat')
print(data.keys())
print(data['Events'].keys())
print(data['Events']['H'].shape)

H = np.transpose(data['Events']['H'])
print(H.shape)
# Out:
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'Events', 'Option', 'Spk', 'behavior']>
# <KeysViewHDF5 ['H', 'Hnanlocs', 'Hvals', 'cellOfWindows', 'cutoffs', 'minRippleThreshold', 'times', 'windows']>
# (3, 326028)
# (326028, 3)
